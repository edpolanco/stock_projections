# %% [markdown]
# ## Making predictions
# > In this notebook we show how we can make predictions with our trained models.

# %% [markdown]
# ### 1) Here we import the `'model'` module
# > The `'model'` module has a predictor class to perform the following tasks:
# > * Download historical prices and prepare the data for NN input.
# > * Select the best trained model to make predicions.
# > * Graph predictions.

# %%
# %load_ext autoreload
# %aimport model
# %autoreload 1

from model import Predictor
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ###  2) Select list of stocks to make predictions
# > Here we select a list of stock we want to make predictions on. We then download historical closing prices on these stocks and prepare the data for input into our trained models.

# %%
#Our prediction list
# FB - Facebook
# KHC - The Kraft Heinz Company
# GOOG - Google 
# C - Citibank
tickers = ['FB','KHC','GOOG','C']

# %%
#Select date range of closing prices
#YYYYMMDD date format
start_date = '20170701' 
end_date = '20180701'

#download quotes from yahoo and save to directory
for ticker in tickers:
    Predictor.download_prep(ticker,start_date,end_date)

# %% [markdown]
# ### 3) Make predictions
#  > * To make predictions we creat an instance of the Predictor class by passing a trade symbol.
#  > * We then select the best model from all the trained models that best fits the historical trading prices of the current stock.
#  > * After a best model is selected we can graph the prediction compared to the actual.

# %% [markdown]
# #### Make predictions for one stock
# > Here we make predictions for one stock where print the test result for each trained model tested.

# %%
stock_1 = tickers[0]
print("***  Closing price prediction for {} *** ".format(stock_1))
pred = Predictor(stock_1)
pred.select_model(verbose=1)
pred.graph()
# Out:
# ***  Closing price prediction for FB ***
# >  1) Now checking model: AAPL   Test error result: 0.0199
# >  2) Now checking model: AXP    Test error result: 0.0176
# >  3) Now checking model: BA     Test error result: 0.0337
# >  4) Now checking model: CAT    Test error result: 0.0374
# >  5) Now checking model: CSCO   Test error result: 0.0342
# >  6) Now checking model: CVX    Test error result: 0.0891
# >  7) Now checking model: DIS    Test error result: 0.0285
# >  8) Now checking model: DWDP   Test error result: 0.0192
# >  9) Now checking model: GS     Test error result: 0.0575
# > 10) Now checking model: HD     Test error result: 0.0561
# > 11) Now checking model: IBM    Test error result: 0.0181
# > 12) Now checking model: INTC   Test error result: 0.0216
# > 13) Now checking model: JNJ    Test error result: 0.2019
# > 14) Now checking model: JPM    Test error result: 0.1258
# > 15) Now checking model: KO     Test error result: 0.1299
# > 16) Now checking model: MCD    Test error result: 0.0197
# > 17) Now checking model: MMM    Test error result: 0.0918
# > 18) Now checking model: MRK    Test error result: 0.0943
# > 19) Now checking model: MSFT   Test error result: 0.0304
# > 20) Now checking model: NKE    Test error result: 0.0315
# > 21) Now checking model: PFE    Test error result: 0.0661
# > 22) Now checking model: PG     Test error result: 0.0718
# > 23) Now checking model: TRV    Test error result: 0.0454
# > 24) Now checking model: UNH    Test error result: 0.0286
# > 25) Now checking model: UTX    Test error result: 0.0683
# > 26) Now checking model: V      Test error result: 0.0576
# > 27) Now checking model: VZ     Test error result: 0.0398
# > 28) Now checking model: WBA    Test error result: 0.0453
# > 29) Now checking model: WMT    Test error result: 0.0554
# > 30) Now checking model: XOM    Test error result: 0.0371
# ==> Best model ticker AXP with error of 0.0176

# %% [markdown]
# #### Make predictions for the remaining stocks

# %%
for ticker in tickers[1:]:
    print("***  Closing price prediction for {} *** ".format(ticker))
    pred = Predictor(ticker)
    pred.select_model(verbose=2)
    pred.graph()
# Out:
# ***  Closing price prediction for KHC ***
# ==> Best model ticker INTC with error of 0.0069
# ***  Closing price prediction for GOOG ***
# ==> Best model ticker TRV with error of 0.0173
# ***  Closing price prediction for C ***
# ==> Best model ticker CVX with error of 0.0196
